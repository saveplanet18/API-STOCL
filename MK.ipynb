# %%
from nsepy import get_history

# %%
from nsetools import Nse

# %%
nse=Nse()

# %%
print(nse)
# Out:
# Driver Class for National Stock Exchange (NSE)

# %%
from datetime import date

# %%
import pandas as pd

# %%
today=date.today()

# %%
print(today)
# Out:
# 2021-01-03

# %%
Jindal_steel=get_history(symbol="JINDALPHOT" , start = date(2019,1,1), end=date(2019,12,31))

# %%
print(Jindal_steel)
# Out:
#                 Symbol Series  Prev Close   Open   High    Low   Last  Close  \
# Date
# 2019-01-01  JINDALPHOT     EQ       31.85  31.85  32.60  31.85  32.60  32.60
# 2019-01-02  JINDALPHOT     EQ       32.60  32.50  32.55  31.60  31.85  31.65
# 2019-01-03  JINDALPHOT     EQ       31.65  31.35  32.20  31.35  31.60  31.60
# 2019-01-04  JINDALPHOT     EQ       31.60  32.00  32.35  31.15  32.35  32.10
# 2019-01-07  JINDALPHOT     EQ       32.10  32.10  32.10  31.50  31.90  31.55
# ...                ...    ...         ...    ...    ...    ...    ...    ...
# 2019-12-24  JINDALPHOT     EQ       14.05  14.05  14.50  12.65  13.45  13.40
# 2019-12-26  JINDALPHOT     EQ       13.40  13.00  14.20  13.00  13.90  13.90
# 2019-12-27  JINDALPHOT     EQ       13.90  14.90  14.90  13.30  13.70  13.70
# 2019-12-30  JINDALPHOT     EQ       13.70  12.85  14.00  12.45  13.65  13.65
# 2019-12-31  JINDALPHOT     EQ       13.65  13.05  14.20  13.05  13.65  13.65
#
# ...

# %%
Apollo_Tyres = get_history(symbol = "APOLLOTYRE", start = date(2019,1,1), end = date(2019,12,31))

# %%
Apollo_Tyres.head() # apollo tyres data
# Out:
#                 Symbol Series  Prev Close    Open    High     Low    Last  \
# Date
# 2019-01-01  APOLLOTYRE     EQ      235.95  236.50  236.50  232.60  234.35
# 2019-01-02  APOLLOTYRE     EQ      234.40  233.00  235.25  229.25  230.20
# 2019-01-03  APOLLOTYRE     EQ      230.85  230.00  232.55  227.35  228.00
# 2019-01-04  APOLLOTYRE     EQ      227.85  228.00  234.25  226.15  233.35
# 2019-01-07  APOLLOTYRE     EQ      233.40  234.85  234.90  229.45  229.45
#
#              Close    VWAP   Volume      Turnover  Trades  Deliverable Volume  \
# Date
# 2019-01-01  234.40  234.28  1125991  2.637968e+13   12331              127543
# 2019-01-02  230.85  232.25  1983510  4.606793e+13   21219              518277
# 2019-01-03  227.85  229.38  1183802  2.715346e+13   31936              247812
# 2019-01-04  233.40  230.61  1540427  3.552405e+13   18417              302763
# 2019-01-07  230.15  232.04   929054  2.155761e+13    8872              165843
#
#             %Deliverble
# Date
# ...

# %%
print(Apollo_Tyres.keys())
# Out:
# Index(['Symbol', 'Series', 'Prev Close', 'Open', 'High', 'Low', 'Last',
#        'Close', 'VWAP', 'Volume', 'Turnover', 'Trades', 'Deliverable Volume',
#        '%Deliverble'],
#       dtype='object')

# %%
n_by_state = Apollo_Tyres.groupby("Symbol")["High"].count()

# %%
print(n_by_state)
# Out:
# Symbol
# APOLLOTYRE    245
# Name: High, dtype: int64

# %%
Apollo_Tyres.index = pd.to_datetime(Apollo_Tyres.index)
Apollo_Tyres = Apollo_Tyres.resample('W').agg({'High': 'max', 'Low': 'min', 'Close': 'last'})
print(Apollo_Tyres) # high & low for data
# Out:
#               High     Low   Close
# Date
# 2019-01-06  236.50  226.15  233.40
# 2019-01-13  234.90  222.00  225.95
# 2019-01-20  227.40  217.25  217.90
# 2019-01-27  220.30  208.75  210.75
# 2019-02-03  212.40  199.30  207.85
# 2019-02-10  209.90  193.80  203.15
# 2019-02-17  205.15  196.70  200.40
# 2019-02-24  211.50  199.65  210.15
# 2019-03-03  220.35  206.45  219.90
# 2019-03-10  225.00  211.50  212.30
# 2019-03-17  235.00  212.35  222.25
# 2019-03-24  224.00  215.00  215.75
# 2019-03-31  224.30  210.00  222.75
# 2019-04-07  227.65  217.00  224.05
# 2019-04-14  225.00  212.50  215.00
# 2019-04-21  221.25  214.35  219.10
# 2019-04-28  217.50  205.25  209.50
# 2019-05-05  209.95  201.10  201.65
# 2019-05-12  202.50  182.20  190.95
# 2019-05-19  190.60  174.00  177.50
# 2019-05-26  197.00  179.35  194.60
# 2019-06-02  200.90  190.70  194.50
# 2019-06-09  202.50  191.45  192.20
# 2019-06-16  198.00  184.00  184.75
# 2019-06-23  202.40  183.90  197.55
# ...

# %%
# Category of Data - Futures
from nsepy import get_quote
from pprint import pprint
from nsepy import get_quote
from nsepy.derivatives import get_expiry_date

expiry = date(2019,12,31)
print(expiry)

data = get_quote('APOLLOTYRE', series='EQ', instrument='FUTIDX', expiry=expiry, option_type='CE', strike=300)
pprint(data)
# Out:
# 2019-12-31
# {'companyName': 'Apollo Tyres Limited',
#  'data': [{}],
#  'eqLink': '/live_market/dynaContent/live_watch/get_quote/GetQuote.jsp?symbol=APOLLOTYRE',
#  'isinCode': None,
#  'lastUpdateTime': '04-JAN-2021 13:00:00',
#  'ocLink': '/marketinfo/sym_map/symbolMapping.jsp?symbol=APOLLOTYRE&instrument=-&date=-&segmentLink=17&symbolCount=2',
#  'tradedDate': '04JAN2021',
#  'valid': 'false'}

# %%
Jindal_steel.to_csv('Jindal_steel1.csv', encoding='utf-8', index=False)
Apollo_Tyres.to_csv('Apollo_Tyres1.csv', encoding='utf-8', index=False)

# %%
# the report is for SPOT or EQUITY and not for futures
adv_dec = nse.get_advances_declines()

# %%
adv_dec
# Out:
# [{'indice': 'NIFTY 50', 'advances': 35.0, 'declines': 15.0, 'unchanged': 0.0},
#  {'indice': 'NIFTY NEXT 50',
#   'advances': 42.0,
#   'declines': 8.0,
#   'unchanged': 0.0},
#  {'indice': 'NIFTY IT', 'advances': 9.0, 'declines': 1.0, 'unchanged': 0.0},
#  {'indice': 'NIFTY BANK', 'advances': 8.0, 'declines': 4.0, 'unchanged': 0.0},
#  {'indice': 'NIFTY MIDCAP 50',
#   'advances': 39.0,
#   'declines': 11.0,
#   'unchanged': 0.0},
#  {'indice': 'NIFTY INFRA',
#   'advances': 21.0,
#   'declines': 9.0,
#   'unchanged': 0.0},
#  {'indice': 'NIFTY REALTY',
#   'advances': 3.0,
#   'declines': 7.0,
#   'unchanged': 0.0},
#  {'indice': 'NIFTY ENERGY',
#   'advances': 7.0,
#   'declines': 3.0,
#   'unchanged': 0.0},
#  {'indice': 'NIFTY FMCG', 'advances': 10.0, 'declines': 5.0, 'unchanged': 0.0},
#  {'indice': 'NIFTY MNC', 'advances': 19.0, 'declines': 11.0, 'unchanged': 0.0},
#  {'indice': 'NIFTY PHARMA',
#   'advances': 10.0,
#   'declines': 0.0,
#   'unchanged': 0.0},
# ...

# %%
top_gainers = nse.get_top_gainers()

# %%
top_gainers
# Out:
# [{'symbol': 'TATASTEEL',
#   'series': 'EQ',
#   'openPrice': 649.0,
#   'highPrice': 676.0,
#   'lowPrice': 646.45,
#   'ltp': 674.5,
#   'previousPrice': 643.1,
#   'netPrice': 4.88,
#   'tradedQuantity': 21992622.0,
#   'turnoverInLakhs': 146275.13,
#   'lastCorpAnnouncementDate': '06-Aug-2020',
#   'lastCorpAnnouncement': 'Dividend - Rs 10 Per Share'},
#  {'symbol': 'HINDALCO',
#   'series': 'EQ',
#   'openPrice': 240.9,
#   'highPrice': 248.8,
#   'lowPrice': 239.55,
#   'ltp': 248.5,
#   'previousPrice': 238.35,
#   'netPrice': 4.26,
#   'tradedQuantity': 13401072.0,
#   'turnoverInLakhs': 32997.46,
#   'lastCorpAnnouncementDate': '03-Sep-2020',
#   'lastCorpAnnouncement': 'Annual General Meeting/Dividend - Re 1 Per Share'},
#  {'symbol': 'GAIL',
#   'series': 'EQ',
#   'openPrice': 124.8,
#   'highPrice': 128.45,
#   'lowPrice': 124.65,
#   'ltp': 128.3,
#   'previousPrice': 123.65,
#   'netPrice': 3.76,
#   'tradedQuantity': 18802419.0,
#   'turnoverInLakhs': 23826.43,
# ...

# %%
top_losers = nse.get_top_losers()

# %%
top_losers
# Out:
# [{'symbol': 'KOTAKBANK',
#   'series': 'EQ',
#   'openPrice': 2004.0,
#   'highPrice': 2005.95,
#   'lowPrice': 1960.0,
#   'ltp': 1965.15,
#   'previousPrice': 1994.05,
#   'netPrice': '-1.45',
#   'tradedQuantity': 1703630.0,
#   'turnoverInLakhs': 33659.64,
#   'lastCorpAnnouncementDate': '12-Jul-2019',
#   'lastCorpAnnouncement': 'Annual General Meeting/Dividend Rs 0.80 Per Share'},
#  {'symbol': 'HEROMOTOCO',
#   'series': 'EQ',
#   'openPrice': 3112.0,
#   'highPrice': 3123.95,
#   'lowPrice': 3051.0,
#   'ltp': 3062.8,
#   'previousPrice': 3102.65,
#   'netPrice': '-1.28',
#   'tradedQuantity': 850935.0,
#   'turnoverInLakhs': 26146.94,
#   'lastCorpAnnouncementDate': '30-Jul-2020',
#   'lastCorpAnnouncement': 'Annual General Meeting/Dividend - Rs 25 Per Share'},
#  {'symbol': 'TITAN',
#   'series': 'EQ',
#   'openPrice': 1566.0,
#   'highPrice': 1567.0,
#   'lowPrice': 1538.0,
#   'ltp': 1541.0,
#   'previousPrice': 1558.6,
#   'netPrice': '-1.13',
# ...

# %%
nse.get_fno_lot_sizes()
# Out:
# {'BANKNIFTY': 25,
#  'NIFTY': 75,
#  'APOLLOHOSP': 500,
#  'ACC': 500,
#  'AMARAJABAT': 1000,
#  'ADANIENT': 2000,
#  'ADANIPORTS': 2500,
#  'AMBUJACEM': 3000,
#  'APOLLOTYRE': 5000,
#  'AUROPHARMA': 650,
#  'BAJAJ-AUTO': 250,
#  'BAJFINANCE': 250,
#  'BANKBARODA': 11700,
#  'BATAINDIA': 550,
#  'BERGEPAINT': 1100,
#  'BHARTIARTL': 1851,
#  'BOSCHLTD': 50,
#  'BPCL': 1800,
#  'BRITANNIA': 200,
#  'CADILAHC': 2200,
#  'CHOLAFIN': 2500,
#  'CIPLA': 1300,
#  'COALINDIA': 4200,
#  'CONCOR': 1563,
#  'CUMMINSIND': 1200,
#  'DABUR': 1250,
#  'DIVISLAB': 200,
#  'DLF': 3300,
#  'DRREDDY': 125,
#  'EICHERMOT': 350,
#  'ESCORTS': 550,
#  'EXIDEIND': 3600,
#  'FEDERALBNK': 10000,
#  'GAIL': 6100,
#  'GODREJCP': 1000,
#  'GODREJPROP': 650,
#  'HDFC': 300,
#  'HEROMOTOCO': 300,
#  'HINDPETRO': 2700,
#  'HINDUNILVR': 300,
#  'ICICIBANK': 1375,
#  'ICICIPRULI': 1500,
#  'IDEA': 70000,
#  'IGL': 1375,
#  'INDIGO': 500,
#  'INFY': 600,
#  'IOC': 6500,
#  'JSWSTEEL': 2700,
#  'JUBLFOOD': 250,
# ...

# %%
# Daily high and low - This is the highest value for each day and the lowest value for each day
from nsepy.history import get_price_list
Apollo_Tyres.index = pd.to_datetime(Apollo_Tyres.index)
Apollo_Tyres = Apollo_Tyres.resample('W').agg({'High': 'max', 'Low': 'min', 'Close': 'last'})
Apollo_Tyres.to_csv('Apollo_Tyreslowhigh.csv', encoding='utf-8', index=False)
print(Apollo_Tyres)
# Out:
#               High     Low   Close
# Date
# 2019-01-06  236.50  226.15  233.40
# 2019-01-13  234.90  222.00  225.95
# 2019-01-20  227.40  217.25  217.90
# 2019-01-27  220.30  208.75  210.75
# 2019-02-03  212.40  199.30  207.85
# 2019-02-10  209.90  193.80  203.15
# 2019-02-17  205.15  196.70  200.40
# 2019-02-24  211.50  199.65  210.15
# 2019-03-03  220.35  206.45  219.90
# 2019-03-10  225.00  211.50  212.30
# 2019-03-17  235.00  212.35  222.25
# 2019-03-24  224.00  215.00  215.75
# 2019-03-31  224.30  210.00  222.75
# 2019-04-07  227.65  217.00  224.05
# 2019-04-14  225.00  212.50  215.00
# 2019-04-21  221.25  214.35  219.10
# 2019-04-28  217.50  205.25  209.50
# 2019-05-05  209.95  201.10  201.65
# 2019-05-12  202.50  182.20  190.95
# 2019-05-19  190.60  174.00  177.50
# 2019-05-26  197.00  179.35  194.60
# 2019-06-02  200.90  190.70  194.50
# 2019-06-09  202.50  191.45  192.20
# 2019-06-16  198.00  184.00  184.75
# 2019-06-23  202.40  183.90  197.55
# ...

# %%
prices = get_price_list(dt=date(2019,1,1))

# %%
prices
# Out:
#           SYMBOL SERIES      OPEN      HIGH      LOW     CLOSE      LAST  \
# 0      20MICRONS     EQ     42.05     44.75     41.7     44.25     44.65
# 1     3IINFOTECH     EQ      3.65      3.65      3.6      3.65      3.65
# 2        3MINDIA     EQ  20854.95  20870.00  20625.0  20666.35  20675.00
# 3         3PLAND     EQ     12.00     12.05     12.0     12.00     12.00
# 4         5PAISA     EQ    257.90    257.90    247.6    257.90    257.90
# ...          ...    ...       ...       ...      ...       ...       ...
# 1828  ZODIACLOTH     EQ    151.15    151.15    142.0    142.70    142.40
# 1829   ZODJRDMKJ     EQ     40.40     43.00     40.4     43.00     43.00
# 1831       ZUARI     EQ    238.05    252.00    235.6    248.15    249.00
# 1832   ZUARIGLOB     EQ    113.55    123.00    113.5    121.40    122.00
# 1833   ZYDUSWELL     EQ   1363.70   1370.25   1351.0   1366.50   1367.50
#
#       PREVCLOSE  TOTTRDQTY    TOTTRDVAL    TIMESTAMP  TOTALTRADES  \
# ...

# %%
prices.to_csv('prices.csv', encoding='utf-8', index=False)

# %%
from nsepy import get_rbi_ref_history
rbi_ref = get_rbi_ref_history(date(2019,1,1), date(2019,12,31))

# %%
rbi_ref
# Out:
#               1 USD    1 GBP   1 EURO  100 YEN
# Date
# 2019-05-10  69.9212  90.9269  78.4884    63.72
# 2019-05-09  69.8685  90.9879  78.2481    63.59
# 2019-05-08  69.6009  90.9002  78.0124    63.23
# 2019-05-07  69.3095  90.9706  77.7010    62.59
# 2019-05-06  69.3558  90.9980  77.6360    62.62
# ...             ...      ...      ...      ...
# 2019-10-24  70.9338  91.6346  78.9810    65.30
# 2019-10-23  70.9373  91.3275  78.9225    65.44
# 2019-10-22  70.8731  91.9602  79.0641    65.26
# 2019-10-18  71.1988  91.5180  79.1854    65.58
# 2019-10-17  71.4087  91.1061  79.0571    65.66
#
# [150 rows x 4 columns]

# %%
# The highest value in a week and the lowest value for the same week
Apollo_Tyres=Apollo_Tyres[Apollo_Tyres['Close']!=0]
Apollo_Tyres["week"]=Apollo_Tyres["Close"].rolling(15).mean()

# %%
Apollo_Tyres
# Out:
#               High     Low   Close     3weekMA        week
# Date
# 2019-01-06  236.50  226.15  233.40         NaN         NaN
# 2019-01-13  234.90  222.00  225.95         NaN         NaN
# 2019-01-20  227.40  217.25  217.90         NaN         NaN
# 2019-01-27  220.30  208.75  210.75         NaN         NaN
# 2019-02-03  212.40  199.30  207.85         NaN         NaN
# 2019-02-10  209.90  193.80  203.15         NaN         NaN
# 2019-02-17  205.15  196.70  200.40         NaN         NaN
# 2019-02-24  211.50  199.65  210.15         NaN         NaN
# 2019-03-03  220.35  206.45  219.90         NaN         NaN
# 2019-03-10  225.00  211.50  212.30         NaN         NaN
# 2019-03-17  235.00  212.35  222.25         NaN         NaN
# 2019-03-24  224.00  215.00  215.75         NaN         NaN
# 2019-03-31  224.30  210.00  222.75         NaN         NaN
# 2019-04-07  227.65  217.00  224.05         NaN         NaN
# 2019-04-14  225.00  212.50  215.00  216.103333  216.103333
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
plt.plot(Apollo_Tyres['Close'].values.tolist()[7:-7])
plt.plot(Apollo_Tyres['week'].values.tolist()[14:])

# %%
import sys
'pandas' in sys.modules
# Out:
# True

# %%
Apollo_Tyres.head()
# Out:
#              High     Low   Close  3weekMA  week
# Date
# 2019-01-06  236.5  226.15  233.40      NaN   NaN
# 2019-01-13  234.9  222.00  225.95      NaN   NaN
# 2019-01-20  227.4  217.25  217.90      NaN   NaN
# 2019-01-27  220.3  208.75  210.75      NaN   NaN
# 2019-02-03  212.4  199.30  207.85      NaN   NaN

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
pylab.rcParams['figure.figsize'] = (15, 9)

# %%
Apollo_Tyres.plot(grid = True)
